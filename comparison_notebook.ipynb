# %%
from preprocessing import preprocess_file

references = preprocess_file("references.txt")
hyp_a = preprocess_file("hypothesis_model_a.txt")
hyp_b = preprocess_file("hypothesis_model_b.txt")

print("Reference:", references[0])
print("Model A:", hyp_a[0])
print("Model B:", hyp_b[0])
# Out:
# Reference: ['the', 'bank', 'approved', 'the', 'loan', 'after', 'reviewing', 'the', 'customers', 'financial', 'history']
# Model A: ['the', 'bank', 'approved', 'the', 'loan', 'after', 'checking', 'the', 'customers', 'financial', 'background']
# Model B: ['the', 'bank', 'said', 'yes', 'to', 'the', 'loan', 'after', 'looking', 'at', 'customer', 'history']

# %%
# !pip install nltk

# %%
# !python evaluate_bleu.py
# Out:
# BLEU (Model A): 0.2817
# BLEU (Model B): 0.0776

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# !python evaluate_meteor.py
# Out:
# METEOR (Model A): 0.5977
# METEOR (Model B): 0.3407

# %%
# !pip install rouge-score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=143d49254bcaa514454685dbaafcf1483e52850d29e6a340c5aa75c29f23cd10
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
# !python evaluate_rouge.py
# Out:
# ROUGE (Model A): {'rouge1_f1': 0.6426103136629453, 'rouge2_f1': 0.4026737967914438, 'rougeL_f1': 0.6426103136629453}
# ROUGE (Model B): {'rouge1_f1': 0.5044858523119392, 'rouge2_f1': 0.16541353383458646, 'rougeL_f1': 0.4727398205659075}

# %%
# !pip install bert-score
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.3 MB/s eta 0:00:00
# ...

# %%
# !python evaluate_bertscore.py
# Out:
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 148kB/s]
# config.json: 100% 482/482 [00:00<00:00, 2.48MB/s]
# vocab.json: 100% 899k/899k [00:00<00:00, 6.92MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 28.9MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 19.5MB/s]
# 2026-01-14 23:21:54.423504: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-14 23:21:54.430204: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-14 23:21:54.443700: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
